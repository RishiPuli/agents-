# %% [markdown]
# #### Tools

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
load_dotenv()
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Hello!")
print(response.content)
# Out:
# Hello there! How can I help you today?

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.tools import tool
load_dotenv()
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

@tool
def get_weather(location:str) -> str:
    """returns weather"""
    return f"{location} is cloudy"
model_with_tools = model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("what is the weather like in India")
print(response)
for tool_call in response.tool_calls:
    print(f"Tool : {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
# Out:
# content='' additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"location": "India"}'}} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019c0315-1768-71d3-9589-a784ad3d789e-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'India'}, 'id': '5f0dd659-a53b-4993-8c51-4ca700b56511', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 15, 'total_tokens': 57, 'input_token_details': {'cache_read': 0}}
# Tool : get_weather
# Args: {'location': 'India'}

# %%
messages = [{"role":"user","content":"What is the weather in Boston?"}]
ai_msg = model_with_tools.invoke(messages)
messages.append(ai_msg)

for tool_call in ai_msg.tool_calls:
    tool_result = get_weather.invoke(tool_call)
    messages.append(tool_result)
final_response = model_with_tools.invoke(messages)
print(final_response.text)
# Out:
# The weather in Boston is cloudy.

# %%
messages
# Out:
# [{'role': 'user', 'content': 'What is the weather in Boston?'},
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"location": "Boston"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c0316-41c8-76e2-ab11-4e4741520d68-0', tool_calls=[{'name': 'get_weather', 'args': {'location': 'Boston'}, 'id': '2440d583-91f1-48e6-83cb-4e222165b7d7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 15, 'total_tokens': 57, 'input_token_details': {'cache_read': 0}}),
#  ToolMessage(content='Boston is cloudy', name='get_weather', tool_call_id='2440d583-91f1-48e6-83cb-4e222165b7d7')]
